# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_iris

# %%
iris = load_iris()
X = iris.data      
y = iris.target

# %%
df = pd.DataFrame(X, columns=iris.feature_names)
df['target'] = y

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
model = DecisionTreeClassifier(random_state=42)
model.fit(X, y)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
scores = cross_val_score(model, X, y, cv=kf, scoring='accuracy')

print("Cross-validation scores for each fold:", scores)
print("Average accuracy:", scores.mean())
# Out:
# Cross-validation scores for each fold: [1.         0.96666667 0.93333333 0.93333333 0.93333333]
# Average accuracy: 0.9533333333333335

# %%
from sklearn.metrics import make_scorer, f1_score
f1_scores = cross_val_score(model, X, y, cv=kf, scoring=make_scorer(f1_score, average='weighted'))
print("F1 scores:", f1_scores)
print("Average F1 score:", f1_scores.mean())
# Out:
# F1 scores: [1.         0.96617827 0.93333333 0.93333333 0.93308081]
# Average F1 score: 0.9531851481851483

# %%
plt.figure(figsize=(8,5))
plt.bar(range(1, len(scores)+1), scores, color='skyblue')
plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.ylim(0, 1)
plt.title('Cross-Validation Accuracy per Fold')
plt.show()

# %%
import joblib
joblib.dump(model, 'cross_val_score.pkl')
# Out:
# ['cross_val_score.pkl']
